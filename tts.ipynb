# %%
# Load the natural_language_augmented dataset
import pandas as pd

# Load the dataset
data = pd.read_csv('natural_math_form.csv', delimiter=';')

# %%
from gtts import gTTS
import os

# Ensure the audios directory exists
if not os.path.exists('audios'):
    os.makedirs('audios')

# Iterate through the dataset and generate audio files for specified columns
for index, row in data.iterrows():
    for col in ["English 1", "English 2", "English 3"]:
        text = row[col]
        if pd.notnull(text):  # Check if the text is not NaN
            tts = gTTS(text=text, lang='en', slow=False)
            audio_path = f'audios_new/v{col[-1]}_f{index+1}.mp3'
            tts.save(audio_path)
            print(f"Saved {audio_path}")
# Out:
# Saved audios_new/v1_f539.mp3
# Saved audios_new/v2_f539.mp3
# Saved audios_new/v3_f539.mp3
# Saved audios_new/v1_f540.mp3
# Saved audios_new/v2_f540.mp3
# Saved audios_new/v3_f540.mp3
# Saved audios_new/v1_f541.mp3
# Saved audios_new/v2_f541.mp3
# Saved audios_new/v3_f541.mp3
# Saved audios_new/v1_f542.mp3
# Saved audios_new/v2_f542.mp3
# Saved audios_new/v3_f542.mp3
# Saved audios_new/v1_f543.mp3
# Saved audios_new/v2_f543.mp3
# Saved audios_new/v3_f543.mp3
# Saved audios_new/v1_f544.mp3
# Saved audios_new/v2_f544.mp3
# Saved audios_new/v3_f544.mp3
# Saved audios_new/v1_f545.mp3
# Saved audios_new/v2_f545.mp3
# Saved audios_new/v3_f545.mp3
# Saved audios_new/v1_f546.mp3
# Saved audios_new/v2_f546.mp3
# Saved audios_new/v3_f546.mp3
# Saved audios_new/v1_f547.mp3
# Saved audios_new/v2_f547.mp3
# Saved audios_new/v3_f547.mp3
# Saved audios_new/v1_f548.mp3
# Saved audios_new/v2_f548.mp3
# Saved audios_new/v3_f548.mp3
# Saved audios_new/v1_f549.mp3
# Saved audios_new/v2_f549.mp3
# Saved audios_new/v3_f549.mp3
# Saved audios_new/v1_f550.mp3
# Saved audios_new/v2_f550.mp3
# Saved audios_new/v3_f550.mp3
# Saved audios_new/v1_f551.mp3
# Saved audios_new/v2_f551.mp3
# Saved audios_new/v3_f551.mp3
# Saved audios_new/v1_f552.mp3
# Saved audios_new/v2_f552.mp3
# Saved audios_new/v3_f552.mp3
# Saved audios_new/v1_f553.mp3
# Saved audios_new/v2_f553.mp3
# Saved audios_new/v3_f553.mp3
# Saved audios_new/v1_f554.mp3
# Saved audios_new/v2_f554.mp3
# Saved audios_new/v3_f554.mp3
# Saved audios_new/v1_f555.mp3
# Saved audios_new/v2_f555.mp3
# Saved audios_new/v3_f555.mp3
# Saved audios_new/v1_f556.mp3
# Saved audios_new/v2_f556.mp3
# Saved audios_new/v3_f556.mp3
# Saved audios_new/v1_f557.mp3
# Saved audios_new/v2_f557.mp3
# Saved audios_new/v3_f557.mp3
# Saved audios_new/v1_f558.mp3
# Saved audios_new/v2_f558.mp3
# Saved audios_new/v3_f558.mp3
# Saved audios_new/v1_f559.mp3
# Saved audios_new/v2_f559.mp3
# Saved audios_new/v3_f559.mp3
# Saved audios_new/v1_f560.mp3
# Saved audios_new/v2_f560.mp3
# Saved audios_new/v3_f560.mp3
# Saved audios_new/v1_f561.mp3
# Saved audios_new/v2_f561.mp3
# Saved audios_new/v3_f561.mp3
# Saved audios_new/v1_f562.mp3
# Saved audios_new/v2_f562.mp3
# Saved audios_new/v3_f562.mp3
# Saved audios_new/v1_f563.mp3
# Saved audios_new/v2_f563.mp3
# Saved audios_new/v3_f563.mp3
# Saved audios_new/v1_f564.mp3
# Saved audios_new/v2_f564.mp3
# Saved audios_new/v3_f564.mp3
# Saved audios_new/v1_f565.mp3
# Saved audios_new/v2_f565.mp3
# Saved audios_new/v3_f565.mp3
# Saved audios_new/v1_f566.mp3
# Saved audios_new/v2_f566.mp3
# Saved audios_new/v3_f566.mp3
# Saved audios_new/v1_f567.mp3
# Saved audios_new/v2_f567.mp3
# Saved audios_new/v3_f567.mp3
# Saved audios_new/v1_f568.mp3
# Saved audios_new/v2_f568.mp3
# Saved audios_new/v3_f568.mp3
# Saved audios_new/v1_f569.mp3
# Saved audios_new/v2_f569.mp3
# Saved audios_new/v3_f569.mp3
# Saved audios_new/v1_f570.mp3
# Saved audios_new/v2_f570.mp3
# Saved audios_new/v3_f570.mp3
# Saved audios_new/v1_f571.mp3
# Saved audios_new/v2_f571.mp3
# Saved audios_new/v3_f571.mp3
# Saved audios_new/v1_f572.mp3
# Saved audios_new/v2_f572.mp3
# Saved audios_new/v3_f572.mp3
# Saved audios_new/v1_f573.mp3
# Saved audios_new/v2_f573.mp3
# Saved audios_new/v3_f573.mp3
# Saved audios_new/v1_f574.mp3
# Saved audios_new/v2_f574.mp3
# Saved audios_new/v3_f574.mp3
# Saved audios_new/v1_f575.mp3
# Saved audios_new/v2_f575.mp3
# Saved audios_new/v3_f575.mp3
# Saved audios_new/v1_f576.mp3
# Saved audios_new/v2_f576.mp3
# Saved audios_new/v3_f576.mp3
# Saved audios_new/v1_f577.mp3
# Saved audios_new/v2_f577.mp3
# Saved audios_new/v3_f577.mp3
# Saved audios_new/v1_f578.mp3
# Saved audios_new/v2_f578.mp3
# Saved audios_new/v3_f578.mp3
# Saved audios_new/v1_f579.mp3
# Saved audios_new/v2_f579.mp3
# Saved audios_new/v3_f579.mp3
# Saved audios_new/v1_f580.mp3
# Saved audios_new/v2_f580.mp3
# Saved audios_new/v3_f580.mp3
# Saved audios_new/v1_f581.mp3
# Saved audios_new/v2_f581.mp3
# Saved audios_new/v3_f581.mp3
# Saved audios_new/v1_f582.mp3
# Saved audios_new/v2_f582.mp3
# Saved audios_new/v3_f582.mp3
# Saved audios_new/v1_f583.mp3
# Saved audios_new/v2_f583.mp3
# Saved audios_new/v3_f583.mp3
# Saved audios_new/v1_f584.mp3
# Saved audios_new/v2_f584.mp3
# Saved audios_new/v3_f584.mp3
# Saved audios_new/v1_f585.mp3
# Saved audios_new/v2_f585.mp3
# Saved audios_new/v3_f585.mp3
# Saved audios_new/v1_f586.mp3
# Saved audios_new/v2_f586.mp3
# Saved audios_new/v3_f586.mp3
# Saved audios_new/v1_f587.mp3
# Saved audios_new/v2_f587.mp3
# Saved audios_new/v3_f587.mp3
# Saved audios_new/v1_f588.mp3
# Saved audios_new/v2_f588.mp3
# Saved audios_new/v3_f588.mp3
# Saved audios_new/v1_f589.mp3
# Saved audios_new/v2_f589.mp3
# Saved audios_new/v3_f589.mp3
# Saved audios_new/v1_f590.mp3
# Saved audios_new/v2_f590.mp3
# Saved audios_new/v3_f590.mp3
# Saved audios_new/v1_f591.mp3
# Saved audios_new/v2_f591.mp3
# Saved audios_new/v3_f591.mp3
# Saved audios_new/v1_f592.mp3
# Saved audios_new/v2_f592.mp3
# Saved audios_new/v3_f592.mp3
# Saved audios_new/v1_f593.mp3
# Saved audios_new/v2_f593.mp3
# Saved audios_new/v3_f593.mp3
# Saved audios_new/v1_f594.mp3
# Saved audios_new/v2_f594.mp3
# Saved audios_new/v3_f594.mp3
# Saved audios_new/v1_f595.mp3
# Saved audios_new/v2_f595.mp3
# Saved audios_new/v3_f595.mp3
# Saved audios_new/v1_f596.mp3
# Saved audios_new/v2_f596.mp3
# Saved audios_new/v3_f596.mp3
# Saved audios_new/v1_f597.mp3
# Saved audios_new/v2_f597.mp3
# Saved audios_new/v3_f597.mp3
# Saved audios_new/v1_f598.mp3
# Saved audios_new/v2_f598.mp3
# Saved audios_new/v3_f598.mp3
# Saved audios_new/v1_f599.mp3
# Saved audios_new/v2_f599.mp3
# Saved audios_new/v3_f599.mp3
# Saved audios_new/v1_f600.mp3
# Saved audios_new/v2_f600.mp3
# Saved audios_new/v3_f600.mp3
# Saved audios_new/v1_f601.mp3
# Saved audios_new/v2_f601.mp3
# Saved audios_new/v3_f601.mp3
# Saved audios_new/v1_f602.mp3
# Saved audios_new/v2_f602.mp3
# Saved audios_new/v3_f602.mp3
# Saved audios_new/v1_f603.mp3
# Saved audios_new/v2_f603.mp3
# Saved audios_new/v3_f603.mp3
# Saved audios_new/v1_f604.mp3
# Saved audios_new/v2_f604.mp3
# Saved audios_new/v3_f604.mp3
# Saved audios_new/v1_f605.mp3
# Saved audios_new/v2_f605.mp3
# Saved audios_new/v3_f605.mp3
# Saved audios_new/v1_f606.mp3
# Saved audios_new/v2_f606.mp3
# Saved audios_new/v3_f606.mp3
# Saved audios_new/v1_f607.mp3
# Saved audios_new/v2_f607.mp3
# Saved audios_new/v3_f607.mp3
# Saved audios_new/v1_f608.mp3
# Saved audios_new/v2_f608.mp3
# Saved audios_new/v3_f608.mp3
# Saved audios_new/v1_f609.mp3
# Saved audios_new/v2_f609.mp3
# Saved audios_new/v3_f609.mp3
# Saved audios_new/v1_f610.mp3
# Saved audios_new/v2_f610.mp3
# Saved audios_new/v3_f610.mp3
# Saved audios_new/v1_f611.mp3
# Saved audios_new/v2_f611.mp3
# Saved audios_new/v3_f611.mp3
# Saved audios_new/v1_f612.mp3
# Saved audios_new/v2_f612.mp3
# Saved audios_new/v3_f612.mp3
# Saved audios_new/v1_f613.mp3
# Saved audios_new/v2_f613.mp3
# Saved audios_new/v3_f613.mp3
# Saved audios_new/v1_f614.mp3
# Saved audios_new/v2_f614.mp3
# Saved audios_new/v3_f614.mp3
# Saved audios_new/v1_f615.mp3
# Saved audios_new/v2_f615.mp3
# Saved audios_new/v3_f615.mp3
# Saved audios_new/v1_f616.mp3
# Saved audios_new/v2_f616.mp3
# Saved audios_new/v3_f616.mp3
# Saved audios_new/v1_f617.mp3
# Saved audios_new/v2_f617.mp3
# Saved audios_new/v3_f617.mp3
# Saved audios_new/v1_f618.mp3
# Saved audios_new/v2_f618.mp3
# Saved audios_new/v3_f618.mp3
# Saved audios_new/v1_f619.mp3
# Saved audios_new/v2_f619.mp3
# Saved audios_new/v3_f619.mp3
# Saved audios_new/v1_f620.mp3
# Saved audios_new/v2_f620.mp3
# Saved audios_new/v3_f620.mp3
# Saved audios_new/v1_f621.mp3
# Saved audios_new/v2_f621.mp3
# Saved audios_new/v3_f621.mp3
# Saved audios_new/v1_f622.mp3
# Saved audios_new/v2_f622.mp3
# Saved audios_new/v3_f622.mp3
# Saved audios_new/v1_f623.mp3
# Saved audios_new/v2_f623.mp3
# Saved audios_new/v3_f623.mp3
# Saved audios_new/v1_f624.mp3
# Saved audios_new/v2_f624.mp3
# Saved audios_new/v3_f624.mp3
# Saved audios_new/v1_f625.mp3
# Saved audios_new/v2_f625.mp3
# Saved audios_new/v3_f625.mp3
# Saved audios_new/v1_f626.mp3
# Saved audios_new/v2_f626.mp3
# Saved audios_new/v3_f626.mp3
# Saved audios_new/v1_f627.mp3
# Saved audios_new/v2_f627.mp3
# Saved audios_new/v3_f627.mp3
# Saved audios_new/v1_f628.mp3
# Saved audios_new/v2_f628.mp3
# Saved audios_new/v3_f628.mp3
# Saved audios_new/v1_f629.mp3
# Saved audios_new/v2_f629.mp3
# Saved audios_new/v3_f629.mp3
# Saved audios_new/v1_f630.mp3
# Saved audios_new/v2_f630.mp3
# Saved audios_new/v3_f630.mp3
# Saved audios_new/v1_f631.mp3
# Saved audios_new/v2_f631.mp3
# Saved audios_new/v3_f631.mp3
# Saved audios_new/v1_f632.mp3
# Saved audios_new/v2_f632.mp3
# Saved audios_new/v3_f632.mp3
# Saved audios_new/v1_f633.mp3
# Saved audios_new/v2_f633.mp3
# Saved audios_new/v3_f633.mp3
# Saved audios_new/v1_f634.mp3
# Saved audios_new/v2_f634.mp3
# Saved audios_new/v3_f634.mp3
# Saved audios_new/v1_f635.mp3
# Saved audios_new/v2_f635.mp3
# Saved audios_new/v3_f635.mp3
# Saved audios_new/v1_f636.mp3
# Saved audios_new/v2_f636.mp3
# Saved audios_new/v3_f636.mp3
# Saved audios_new/v1_f637.mp3
# Saved audios_new/v2_f637.mp3
# Saved audios_new/v3_f637.mp3
# Saved audios_new/v1_f638.mp3
# Saved audios_new/v2_f638.mp3
# Saved audios_new/v3_f638.mp3
# Saved audios_new/v1_f639.mp3
# Saved audios_new/v2_f639.mp3
# Saved audios_new/v3_f639.mp3
# Saved audios_new/v1_f640.mp3
# Saved audios_new/v2_f640.mp3
# Saved audios_new/v3_f640.mp3
# Saved audios_new/v1_f641.mp3
# Saved audios_new/v2_f641.mp3
# Saved audios_new/v3_f641.mp3
# Saved audios_new/v1_f642.mp3
# Saved audios_new/v2_f642.mp3
# Saved audios_new/v3_f642.mp3
# Saved audios_new/v1_f643.mp3
# Saved audios_new/v2_f643.mp3
# Saved audios_new/v3_f643.mp3
# Saved audios_new/v1_f644.mp3
# Saved audios_new/v2_f644.mp3
# Saved audios_new/v3_f644.mp3
# Saved audios_new/v1_f645.mp3
# Saved audios_new/v2_f645.mp3
# Saved audios_new/v3_f645.mp3
# Saved audios_new/v1_f646.mp3
# Saved audios_new/v2_f646.mp3
# Saved audios_new/v3_f646.mp3
# Saved audios_new/v1_f647.mp3
# Saved audios_new/v2_f647.mp3
# Saved audios_new/v3_f647.mp3
# Saved audios_new/v1_f648.mp3
# Saved audios_new/v2_f648.mp3
# Saved audios_new/v3_f648.mp3
# Saved audios_new/v1_f649.mp3
# Saved audios_new/v2_f649.mp3
# Saved audios_new/v3_f649.mp3
# Saved audios_new/v1_f650.mp3
# Saved audios_new/v2_f650.mp3
# Saved audios_new/v3_f650.mp3
# Saved audios_new/v1_f651.mp3
# Saved audios_new/v2_f651.mp3
# Saved audios_new/v3_f651.mp3
# Saved audios_new/v1_f652.mp3
# Saved audios_new/v2_f652.mp3
# Saved audios_new/v3_f652.mp3
# Saved audios_new/v1_f653.mp3
# Saved audios_new/v2_f653.mp3
# Saved audios_new/v3_f653.mp3
# Saved audios_new/v1_f654.mp3
# Saved audios_new/v2_f654.mp3
# Saved audios_new/v3_f654.mp3
# Saved audios_new/v1_f655.mp3
# Saved audios_new/v2_f655.mp3
# Saved audios_new/v3_f655.mp3
# Saved audios_new/v1_f656.mp3
# Saved audios_new/v2_f656.mp3
# Saved audios_new/v3_f656.mp3
# Saved audios_new/v1_f657.mp3
# Saved audios_new/v2_f657.mp3
# Saved audios_new/v3_f657.mp3
# Saved audios_new/v1_f658.mp3
# Saved audios_new/v2_f658.mp3
# Saved audios_new/v3_f658.mp3
# Saved audios_new/v1_f659.mp3
# Saved audios_new/v2_f659.mp3
# Saved audios_new/v3_f659.mp3
# Saved audios_new/v1_f660.mp3
# Saved audios_new/v2_f660.mp3
# Saved audios_new/v3_f660.mp3
# Saved audios_new/v1_f661.mp3
# Saved audios_new/v2_f661.mp3
# Saved audios_new/v3_f661.mp3
# Saved audios_new/v1_f662.mp3
# Saved audios_new/v2_f662.mp3
# Saved audios_new/v3_f662.mp3
# Saved audios_new/v1_f663.mp3
# Saved audios_new/v2_f663.mp3
# Saved audios_new/v3_f663.mp3
# Saved audios_new/v1_f664.mp3
# Saved audios_new/v2_f664.mp3
# Saved audios_new/v3_f664.mp3
# Saved audios_new/v1_f665.mp3
# Saved audios_new/v2_f665.mp3
# Saved audios_new/v3_f665.mp3
# Saved audios_new/v1_f666.mp3
# Saved audios_new/v2_f666.mp3
# Saved audios_new/v3_f666.mp3
# Saved audios_new/v1_f667.mp3
# Saved audios_new/v2_f667.mp3
# Saved audios_new/v3_f667.mp3
# Saved audios_new/v1_f668.mp3
# Saved audios_new/v2_f668.mp3
# Saved audios_new/v3_f668.mp3
# Saved audios_new/v1_f669.mp3
# Saved audios_new/v2_f669.mp3
# Saved audios_new/v3_f669.mp3
# Saved audios_new/v1_f670.mp3
# Saved audios_new/v2_f670.mp3
# Saved audios_new/v3_f670.mp3
# Saved audios_new/v1_f671.mp3
# Saved audios_new/v2_f671.mp3
# Saved audios_new/v3_f671.mp3
# Saved audios_new/v1_f672.mp3
# Saved audios_new/v2_f672.mp3
# Saved audios_new/v3_f672.mp3
# Saved audios_new/v1_f673.mp3
# Saved audios_new/v2_f673.mp3
# Saved audios_new/v3_f673.mp3
# Saved audios_new/v1_f674.mp3
# Saved audios_new/v2_f674.mp3
# Saved audios_new/v3_f674.mp3
# Saved audios_new/v1_f675.mp3
# Saved audios_new/v2_f675.mp3
# Saved audios_new/v3_f675.mp3
# Saved audios_new/v1_f676.mp3
# Saved audios_new/v2_f676.mp3
# Saved audios_new/v3_f676.mp3
# Saved audios_new/v1_f677.mp3
# Saved audios_new/v2_f677.mp3
# Saved audios_new/v3_f677.mp3
# Saved audios_new/v1_f678.mp3
# Saved audios_new/v2_f678.mp3
# Saved audios_new/v3_f678.mp3
# Saved audios_new/v1_f679.mp3
# Saved audios_new/v2_f679.mp3
# Saved audios_new/v3_f679.mp3
# Saved audios_new/v1_f680.mp3
# Saved audios_new/v2_f680.mp3
# Saved audios_new/v3_f680.mp3
# Saved audios_new/v1_f681.mp3
# Saved audios_new/v2_f681.mp3
# Saved audios_new/v3_f681.mp3
# Saved audios_new/v1_f682.mp3
# Saved audios_new/v2_f682.mp3
# Saved audios_new/v3_f682.mp3
# Saved audios_new/v1_f683.mp3
# Saved audios_new/v2_f683.mp3
# Saved audios_new/v3_f683.mp3
# Saved audios_new/v1_f684.mp3
# Saved audios_new/v2_f684.mp3
# Saved audios_new/v3_f684.mp3
# Saved audios_new/v1_f685.mp3
# Saved audios_new/v2_f685.mp3
# Saved audios_new/v3_f685.mp3
# Saved audios_new/v1_f686.mp3
# Saved audios_new/v2_f686.mp3
# Saved audios_new/v3_f686.mp3
# Saved audios_new/v1_f687.mp3
# Saved audios_new/v2_f687.mp3
# Saved audios_new/v3_f687.mp3
# Saved audios_new/v1_f688.mp3
# Saved audios_new/v2_f688.mp3
# Saved audios_new/v3_f688.mp3
# Saved audios_new/v1_f689.mp3
# Saved audios_new/v2_f689.mp3
# Saved audios_new/v3_f689.mp3
# Saved audios_new/v1_f690.mp3
# Saved audios_new/v2_f690.mp3
# Saved audios_new/v3_f690.mp3
# Saved audios_new/v1_f691.mp3
# Saved audios_new/v2_f691.mp3
# Saved audios_new/v3_f691.mp3
# Saved audios_new/v1_f692.mp3
# Saved audios_new/v2_f692.mp3
# Saved audios_new/v3_f692.mp3
# Saved audios_new/v1_f693.mp3
# Saved audios_new/v2_f693.mp3
# Saved audios_new/v3_f693.mp3
# Saved audios_new/v1_f694.mp3
# Saved audios_new/v2_f694.mp3
# Saved audios_new/v3_f694.mp3
# Saved audios_new/v1_f695.mp3
# Saved audios_new/v2_f695.mp3
# Saved audios_new/v3_f695.mp3
# Saved audios_new/v1_f696.mp3
# Saved audios_new/v2_f696.mp3
# Saved audios_new/v3_f696.mp3
# Saved audios_new/v1_f697.mp3
# Saved audios_new/v2_f697.mp3
# Saved audios_new/v3_f697.mp3
# Saved audios_new/v1_f698.mp3
# Saved audios_new/v2_f698.mp3
# Saved audios_new/v3_f698.mp3
# Saved audios_new/v1_f699.mp3
# Saved audios_new/v2_f699.mp3
# Saved audios_new/v3_f699.mp3
# Saved audios_new/v1_f700.mp3
# Saved audios_new/v2_f700.mp3
# Saved audios_new/v3_f700.mp3
# Saved audios_new/v1_f701.mp3
# Saved audios_new/v2_f701.mp3
# Saved audios_new/v3_f701.mp3
# Saved audios_new/v1_f702.mp3
# Saved audios_new/v2_f702.mp3
# Saved audios_new/v3_f702.mp3
# Saved audios_new/v1_f703.mp3
# Saved audios_new/v2_f703.mp3
# Saved audios_new/v3_f703.mp3
# Saved audios_new/v1_f704.mp3
# Saved audios_new/v2_f704.mp3
# Saved audios_new/v3_f704.mp3
# Saved audios_new/v1_f705.mp3
# Saved audios_new/v2_f705.mp3
# Saved audios_new/v3_f705.mp3
# Saved audios_new/v1_f706.mp3
# Saved audios_new/v2_f706.mp3
# Saved audios_new/v3_f706.mp3
# Saved audios_new/v1_f707.mp3
# Saved audios_new/v2_f707.mp3
# Saved audios_new/v3_f707.mp3
# Saved audios_new/v1_f708.mp3
# Saved audios_new/v2_f708.mp3
# Saved audios_new/v3_f708.mp3
# Saved audios_new/v1_f709.mp3
# Saved audios_new/v2_f709.mp3
# Saved audios_new/v3_f709.mp3
# Saved audios_new/v1_f710.mp3
# Saved audios_new/v2_f710.mp3
# Saved audios_new/v3_f710.mp3
# Saved audios_new/v1_f711.mp3
# Saved audios_new/v2_f711.mp3
# Saved audios_new/v3_f711.mp3
# Saved audios_new/v1_f712.mp3
# Saved audios_new/v2_f712.mp3
# Saved audios_new/v3_f712.mp3
# Saved audios_new/v1_f713.mp3
# Saved audios_new/v2_f713.mp3
# Saved audios_new/v3_f713.mp3
# Saved audios_new/v1_f714.mp3
# Saved audios_new/v2_f714.mp3
# Saved audios_new/v3_f714.mp3
# Saved audios_new/v1_f715.mp3
# Saved audios_new/v2_f715.mp3
# Saved audios_new/v3_f715.mp3
# Saved audios_new/v1_f716.mp3
# Saved audios_new/v2_f716.mp3
# Saved audios_new/v3_f716.mp3
# Saved audios_new/v1_f717.mp3
# Saved audios_new/v2_f717.mp3
# Saved audios_new/v3_f717.mp3
# Saved audios_new/v1_f718.mp3
# Saved audios_new/v2_f718.mp3
# Saved audios_new/v3_f718.mp3
# Saved audios_new/v1_f719.mp3
# Saved audios_new/v2_f719.mp3
# Saved audios_new/v3_f719.mp3
# Saved audios_new/v1_f720.mp3
# Saved audios_new/v2_f720.mp3
# Saved audios_new/v3_f720.mp3
# Saved audios_new/v1_f721.mp3
# Saved audios_new/v2_f721.mp3
# Saved audios_new/v3_f721.mp3
# Saved audios_new/v1_f722.mp3
# Saved audios_new/v2_f722.mp3
# Saved audios_new/v3_f722.mp3
# Saved audios_new/v1_f723.mp3
# Saved audios_new/v2_f723.mp3
# Saved audios_new/v3_f723.mp3
# Saved audios_new/v1_f724.mp3
# Saved audios_new/v2_f724.mp3
# Saved audios_new/v3_f724.mp3
# Saved audios_new/v1_f725.mp3
# Saved audios_new/v2_f725.mp3
# Saved audios_new/v3_f725.mp3
# Saved audios_new/v1_f726.mp3
# Saved audios_new/v2_f726.mp3
# Saved audios_new/v3_f726.mp3
# Saved audios_new/v1_f727.mp3
# Saved audios_new/v2_f727.mp3
# Saved audios_new/v3_f727.mp3
# Saved audios_new/v1_f728.mp3
# Saved audios_new/v2_f728.mp3
# Saved audios_new/v3_f728.mp3
# Saved audios_new/v1_f729.mp3
# Saved audios_new/v2_f729.mp3
# Saved audios_new/v3_f729.mp3
# Saved audios_new/v1_f730.mp3
# Saved audios_new/v2_f730.mp3
# Saved audios_new/v3_f730.mp3
# Saved audios_new/v1_f731.mp3
# Saved audios_new/v2_f731.mp3
# Saved audios_new/v3_f731.mp3
# Saved audios_new/v1_f732.mp3
# Saved audios_new/v2_f732.mp3
# Saved audios_new/v3_f732.mp3
# Saved audios_new/v1_f733.mp3
# Saved audios_new/v2_f733.mp3
# Saved audios_new/v3_f733.mp3
# Saved audios_new/v1_f734.mp3
# Saved audios_new/v2_f734.mp3
# Saved audios_new/v3_f734.mp3
# Saved audios_new/v1_f735.mp3
# Saved audios_new/v2_f735.mp3
# Saved audios_new/v3_f735.mp3
# Saved audios_new/v1_f736.mp3
# Saved audios_new/v2_f736.mp3
# Saved audios_new/v3_f736.mp3
# Saved audios_new/v1_f737.mp3
# Saved audios_new/v2_f737.mp3
# Saved audios_new/v3_f737.mp3
# Saved audios_new/v1_f738.mp3
# Saved audios_new/v2_f738.mp3
# Saved audios_new/v3_f738.mp3
# Saved audios_new/v1_f739.mp3
# Saved audios_new/v2_f739.mp3
# Saved audios_new/v3_f739.mp3
# Saved audios_new/v1_f740.mp3
# Saved audios_new/v2_f740.mp3
# Saved audios_new/v3_f740.mp3
# Saved audios_new/v1_f741.mp3
# Saved audios_new/v2_f741.mp3
# Saved audios_new/v3_f741.mp3
# Saved audios_new/v1_f742.mp3
# Saved audios_new/v2_f742.mp3
# Saved audios_new/v3_f742.mp3
# Saved audios_new/v1_f743.mp3
# Saved audios_new/v2_f743.mp3
# Saved audios_new/v3_f743.mp3
# Saved audios_new/v1_f744.mp3
# Saved audios_new/v2_f744.mp3
# Saved audios_new/v3_f744.mp3
# Saved audios_new/v1_f745.mp3
# Saved audios_new/v2_f745.mp3
# Saved audios_new/v3_f745.mp3
# Saved audios_new/v1_f746.mp3
# Saved audios_new/v2_f746.mp3
# Saved audios_new/v3_f746.mp3
# Saved audios_new/v1_f747.mp3
# Saved audios_new/v2_f747.mp3
# Saved audios_new/v3_f747.mp3
# Saved audios_new/v1_f748.mp3
# Saved audios_new/v2_f748.mp3
# Saved audios_new/v3_f748.mp3
# Saved audios_new/v1_f749.mp3
# Saved audios_new/v2_f749.mp3
# Saved audios_new/v3_f749.mp3
# Saved audios_new/v1_f750.mp3
# Saved audios_new/v2_f750.mp3
# Saved audios_new/v3_f750.mp3
# Saved audios_new/v1_f751.mp3
# Saved audios_new/v2_f751.mp3
# Saved audios_new/v3_f751.mp3
# Saved audios_new/v1_f752.mp3
# Saved audios_new/v2_f752.mp3
# Saved audios_new/v3_f752.mp3
# Saved audios_new/v1_f753.mp3
# Saved audios_new/v2_f753.mp3
# Saved audios_new/v3_f753.mp3
# Saved audios_new/v1_f754.mp3
# Saved audios_new/v2_f754.mp3
# Saved audios_new/v3_f754.mp3
# Saved audios_new/v1_f755.mp3
# Saved audios_new/v2_f755.mp3
# Saved audios_new/v3_f755.mp3
# Saved audios_new/v1_f756.mp3
# Saved audios_new/v2_f756.mp3
# Saved audios_new/v3_f756.mp3
# Saved audios_new/v1_f757.mp3
# Saved audios_new/v2_f757.mp3
# Saved audios_new/v3_f757.mp3
# Saved audios_new/v1_f758.mp3
# Saved audios_new/v2_f758.mp3
# Saved audios_new/v3_f758.mp3
# Saved audios_new/v1_f759.mp3
# Saved audios_new/v2_f759.mp3
# Saved audios_new/v3_f759.mp3
# Saved audios_new/v1_f760.mp3
# Saved audios_new/v2_f760.mp3
# Saved audios_new/v3_f760.mp3
# Saved audios_new/v1_f761.mp3
# Saved audios_new/v2_f761.mp3
# Saved audios_new/v3_f761.mp3
# Saved audios_new/v1_f762.mp3
# Saved audios_new/v2_f762.mp3
# Saved audios_new/v3_f762.mp3
# Saved audios_new/v1_f763.mp3
# Saved audios_new/v2_f763.mp3
# Saved audios_new/v3_f763.mp3
# Saved audios_new/v1_f764.mp3
# Saved audios_new/v2_f764.mp3
# Saved audios_new/v3_f764.mp3
# Saved audios_new/v1_f765.mp3
# Saved audios_new/v2_f765.mp3
# Saved audios_new/v3_f765.mp3
# Saved audios_new/v1_f766.mp3
# Saved audios_new/v2_f766.mp3
# Saved audios_new/v3_f766.mp3
# Saved audios_new/v1_f767.mp3
# Saved audios_new/v2_f767.mp3
# Saved audios_new/v3_f767.mp3
# Saved audios_new/v1_f768.mp3
# Saved audios_new/v2_f768.mp3
# Saved audios_new/v3_f768.mp3
# Saved audios_new/v1_f769.mp3
# Saved audios_new/v2_f769.mp3
# Saved audios_new/v3_f769.mp3
# Saved audios_new/v1_f770.mp3
# Saved audios_new/v2_f770.mp3
# Saved audios_new/v3_f770.mp3
# Saved audios_new/v1_f771.mp3
# Saved audios_new/v2_f771.mp3
# Saved audios_new/v3_f771.mp3
# Saved audios_new/v1_f772.mp3
# Saved audios_new/v2_f772.mp3
# Saved audios_new/v3_f772.mp3
# Saved audios_new/v1_f773.mp3
# Saved audios_new/v2_f773.mp3
# Saved audios_new/v3_f773.mp3
# Saved audios_new/v1_f774.mp3
# Saved audios_new/v2_f774.mp3
# Saved audios_new/v3_f774.mp3
# Saved audios_new/v1_f775.mp3
# Saved audios_new/v2_f775.mp3
# Saved audios_new/v3_f775.mp3
# Saved audios_new/v1_f776.mp3
# Saved audios_new/v2_f776.mp3
# Saved audios_new/v3_f776.mp3
# Saved audios_new/v1_f777.mp3
# Saved audios_new/v2_f777.mp3
# Saved audios_new/v3_f777.mp3
# Saved audios_new/v1_f778.mp3
# Saved audios_new/v2_f778.mp3
# Saved audios_new/v3_f778.mp3
# Saved audios_new/v1_f779.mp3
# Saved audios_new/v2_f779.mp3
# Saved audios_new/v3_f779.mp3
# Saved audios_new/v1_f780.mp3
# Saved audios_new/v2_f780.mp3
# Saved audios_new/v3_f780.mp3
# Saved audios_new/v1_f781.mp3
# Saved audios_new/v2_f781.mp3
# Saved audios_new/v3_f781.mp3
# Saved audios_new/v1_f782.mp3
# Saved audios_new/v2_f782.mp3
# Saved audios_new/v3_f782.mp3
# Saved audios_new/v1_f783.mp3
# Saved audios_new/v2_f783.mp3
# Saved audios_new/v3_f783.mp3
# Saved audios_new/v1_f784.mp3
# Saved audios_new/v2_f784.mp3
# Saved audios_new/v3_f784.mp3
# Saved audios_new/v1_f785.mp3
# Saved audios_new/v2_f785.mp3
# Saved audios_new/v3_f785.mp3
# Saved audios_new/v1_f786.mp3
# Saved audios_new/v2_f786.mp3
# Saved audios_new/v3_f786.mp3
# Saved audios_new/v1_f787.mp3
# Saved audios_new/v2_f787.mp3
# Saved audios_new/v3_f787.mp3
# Saved audios_new/v1_f788.mp3
# Saved audios_new/v2_f788.mp3
# Saved audios_new/v3_f788.mp3
# Saved audios_new/v1_f789.mp3
# Saved audios_new/v2_f789.mp3
# Saved audios_new/v3_f789.mp3
# Saved audios_new/v1_f790.mp3
# Saved audios_new/v2_f790.mp3
# Saved audios_new/v3_f790.mp3
# Saved audios_new/v1_f791.mp3
# Saved audios_new/v2_f791.mp3
# Saved audios_new/v3_f791.mp3
# Saved audios_new/v1_f792.mp3
# Saved audios_new/v2_f792.mp3
# Saved audios_new/v3_f792.mp3
# Saved audios_new/v1_f793.mp3
# Saved audios_new/v2_f793.mp3
# Saved audios_new/v3_f793.mp3
# Saved audios_new/v1_f794.mp3
# Saved audios_new/v2_f794.mp3
# Saved audios_new/v3_f794.mp3
# Saved audios_new/v1_f795.mp3
# Saved audios_new/v2_f795.mp3
# Saved audios_new/v3_f795.mp3
# Saved audios_new/v1_f796.mp3
# Saved audios_new/v2_f796.mp3
# Saved audios_new/v3_f796.mp3
# Saved audios_new/v1_f797.mp3
# Saved audios_new/v2_f797.mp3
# Saved audios_new/v3_f797.mp3
# Saved audios_new/v1_f798.mp3
# Saved audios_new/v2_f798.mp3
# Saved audios_new/v3_f798.mp3
# Saved audios_new/v1_f799.mp3
# Saved audios_new/v2_f799.mp3
# Saved audios_new/v3_f799.mp3
# Saved audios_new/v1_f800.mp3
# Saved audios_new/v2_f800.mp3
# Saved audios_new/v3_f800.mp3
# Saved audios_new/v1_f801.mp3
# Saved audios_new/v2_f801.mp3
# Saved audios_new/v3_f801.mp3
# Saved audios_new/v1_f802.mp3
# Saved audios_new/v2_f802.mp3
# Saved audios_new/v3_f802.mp3
# Saved audios_new/v1_f803.mp3
# Saved audios_new/v2_f803.mp3
# Saved audios_new/v3_f803.mp3
# Saved audios_new/v1_f804.mp3
# Saved audios_new/v2_f804.mp3
# Saved audios_new/v3_f804.mp3
# Saved audios_new/v1_f805.mp3
# Saved audios_new/v2_f805.mp3
# Saved audios_new/v3_f805.mp3
# Saved audios_new/v1_f806.mp3
# Saved audios_new/v2_f806.mp3
# Saved audios_new/v3_f806.mp3
# Saved audios_new/v1_f807.mp3
# Saved audios_new/v2_f807.mp3
# Saved audios_new/v3_f807.mp3
# Saved audios_new/v1_f808.mp3
# Saved audios_new/v2_f808.mp3
# Saved audios_new/v3_f808.mp3
# Saved audios_new/v1_f809.mp3
# Saved audios_new/v2_f809.mp3
# Saved audios_new/v3_f809.mp3
# Saved audios_new/v1_f810.mp3
# Saved audios_new/v2_f810.mp3
# Saved audios_new/v3_f810.mp3
# Saved audios_new/v1_f811.mp3
# Saved audios_new/v2_f811.mp3
# Saved audios_new/v3_f811.mp3
# Saved audios_new/v1_f812.mp3
# Saved audios_new/v2_f812.mp3
# Saved audios_new/v3_f812.mp3
# Saved audios_new/v1_f813.mp3
# Saved audios_new/v2_f813.mp3
# Saved audios_new/v3_f813.mp3
# Saved audios_new/v1_f814.mp3
# Saved audios_new/v2_f814.mp3
# Saved audios_new/v3_f814.mp3
# Saved audios_new/v1_f815.mp3
# Saved audios_new/v2_f815.mp3
# Saved audios_new/v3_f815.mp3
# Saved audios_new/v1_f816.mp3
# Saved audios_new/v2_f816.mp3
# Saved audios_new/v3_f816.mp3
# Saved audios_new/v1_f817.mp3
# Saved audios_new/v2_f817.mp3
# Saved audios_new/v3_f817.mp3
# Saved audios_new/v1_f818.mp3
# Saved audios_new/v2_f818.mp3
# Saved audios_new/v3_f818.mp3
# Saved audios_new/v1_f819.mp3
# Saved audios_new/v2_f819.mp3
# Saved audios_new/v3_f819.mp3
# Saved audios_new/v1_f820.mp3
# Saved audios_new/v2_f820.mp3
# Saved audios_new/v3_f820.mp3
# Saved audios_new/v1_f821.mp3
# Saved audios_new/v2_f821.mp3
# Saved audios_new/v3_f821.mp3
# Saved audios_new/v1_f822.mp3
# Saved audios_new/v2_f822.mp3
# Saved audios_new/v3_f822.mp3
# Saved audios_new/v1_f823.mp3
# Saved audios_new/v2_f823.mp3
# Saved audios_new/v3_f823.mp3
